# %%
import dataclasses

import jax

from openpi.models import model as _model
from openpi.policies import droid_policy
from openpi.policies import policy_config as _policy_config
from openpi.shared import download
from openpi.training import config as _config
from openpi.training import data_loader as _data_loader

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['XLA_FLAGS'] = '--xla_gpu_strict_conv_algorithm_picker=false'
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE'] = 'false'
os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION'] = '0.90'

# %% [markdown]
# # Policy inference
#
# The following example shows how to create a policy from a checkpoint and run inference on a dummy example.

# %%
config = _config.get_config("pi0_fast_droid")
checkpoint_dir = download.maybe_download("gs://openpi-assets/checkpoints/pi05_droid")

# Create a trained policy.
policy = _policy_config.create_trained_policy(config, checkpoint_dir)

# Run inference on a dummy example. This example corresponds to observations produced by the DROID runtime.
example = droid_policy.make_droid_example()
result = policy.infer(example)

# Delete the policy to free up memory.
del policy

print("Actions shape:", result["actions"].shape)
# Out:
#   0%|          | 0.00/10.1G [00:00<?, ?iB/s]
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-26' coro=<_run_coros_in_chunks.<locals>._run_coro() done, defined at /home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/fsspec/asyn.py:243> exception=OSError(28, 'No space left on device')>
# Traceback (most recent call last):
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/fsspec/asyn.py", line 245, in _run_coro
#     return await asyncio.wait_for(coro, timeout=timeout), i
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/asyncio/tasks.py", line 452, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/fsspec/callbacks.py", line 81, in func
#     return await fn(path1, path2, callback=child, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/gcsfs/core.py", line 1613, in _get_file
#     await self._get_file_request(u2, lpath, callback=callback, **kwargs)
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/decorator.py", line 224, in fun
#     return await caller(func, *(extras + args), **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/gcsfs/retry.py", line 135, in retry_request
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/gcsfs/core.py", line 1600, in _get_file_request
#     f2.write(data)
# OSError: [Errno 28] No space left on device
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-30' coro=<_run_coros_in_chunks.<locals>._run_coro() done, defined at /home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/fsspec/asyn.py:243> exception=OSError(28, 'No space left on device')>
# Traceback (most recent call last):
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/fsspec/asyn.py", line 245, in _run_coro
#     return await asyncio.wait_for(coro, timeout=timeout), i
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/asyncio/tasks.py", line 452, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/fsspec/callbacks.py", line 81, in func
#     return await fn(path1, path2, callback=child, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/gcsfs/core.py", line 1613, in _get_file
#     await self._get_file_request(u2, lpath, callback=callback, **kwargs)
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/decorator.py", line 224, in fun
#     return await caller(func, *(extras + args), **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/gcsfs/retry.py", line 135, in retry_request
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/gcsfs/core.py", line 1600, in _get_file_request
#     f2.write(data)
# OSError: [Errno 28] No space left on device
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-31' coro=<_run_coros_in_chunks.<locals>._run_coro() done, defined at /home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/fsspec/asyn.py:243> exception=OSError(28, 'No space left on device')>
# Traceback (most recent call last):
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/fsspec/asyn.py", line 245, in _run_coro
#     return await asyncio.wait_for(coro, timeout=timeout), i
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/asyncio/tasks.py", line 452, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/fsspec/callbacks.py", line 81, in func
#     return await fn(path1, path2, callback=child, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/gcsfs/core.py", line 1613, in _get_file
#     await self._get_file_request(u2, lpath, callback=callback, **kwargs)
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/decorator.py", line 224, in fun
#     return await caller(func, *(extras + args), **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/gcsfs/retry.py", line 135, in retry_request
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/gcsfs/core.py", line 1600, in _get_file_request
#     f2.write(data)
# OSError: [Errno 28] No space left on device
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-34' coro=<_run_coros_in_chunks.<locals>._run_coro() done, defined at /home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/fsspec/asyn.py:243> exception=OSError(28, 'No space left on device')>
# Traceback (most recent call last):
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/gcsfs/core.py", line 1600, in _get_file_request
#     f2.write(data)
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/fsspec/asyn.py", line 245, in _run_coro
#     return await asyncio.wait_for(coro, timeout=timeout), i
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/asyncio/tasks.py", line 452, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/fsspec/callbacks.py", line 81, in func
#     return await fn(path1, path2, callback=child, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/gcsfs/core.py", line 1613, in _get_file
#     await self._get_file_request(u2, lpath, callback=callback, **kwargs)
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/decorator.py", line 224, in fun
#     return await caller(func, *(extras + args), **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/gcsfs/retry.py", line 135, in retry_request
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/gcsfs/core.py", line 1595, in _get_file_request
#     with open(lpath, "wb") as f2:
# OSError: [Errno 28] No space left on device
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-35' coro=<_run_coros_in_chunks.<locals>._run_coro() done, defined at /home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/fsspec/asyn.py:243> exception=OSError(28, 'No space left on device')>
# Traceback (most recent call last):
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/fsspec/asyn.py", line 245, in _run_coro
#     return await asyncio.wait_for(coro, timeout=timeout), i
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/asyncio/tasks.py", line 452, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/fsspec/callbacks.py", line 81, in func
#     return await fn(path1, path2, callback=child, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/gcsfs/core.py", line 1613, in _get_file
#     await self._get_file_request(u2, lpath, callback=callback, **kwargs)
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/decorator.py", line 224, in fun
#     return await caller(func, *(extras + args), **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/gcsfs/retry.py", line 135, in retry_request
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yahuanshi/OpenPI/openpi/.venv/lib/python3.11/site-packages/gcsfs/core.py", line 1600, in _get_file_request
#     f2.write(data)
# OSError: [Errno 28] No space left on device
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=ClientConnectionError('Connection lost: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)')>
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/asyncio/sslproto.py", line 648, in _do_shutdown
#     self._sslobj.unwrap()
#   File "/usr/lib/python3.11/ssl.py", line 983, in unwrap
#     return self._sslobj.shutdown()
#            ^^^^^^^^^^^^^^^^^^^^^^^
# ssl.SSLError: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)
#
# The above exception was the direct cause of the following exception:
#
# aiohttp.client_exceptions.ClientConnectionError: Connection lost: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=ClientConnectionError('Connection lost: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)')>
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/asyncio/sslproto.py", line 648, in _do_shutdown
#     self._sslobj.unwrap()
#   File "/usr/lib/python3.11/ssl.py", line 983, in unwrap
#     return self._sslobj.shutdown()
#            ^^^^^^^^^^^^^^^^^^^^^^^
# ssl.SSLError: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)
#
# The above exception was the direct cause of the following exception:
#
# aiohttp.client_exceptions.ClientConnectionError: Connection lost: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=ClientConnectionError('Connection lost: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)')>
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/asyncio/sslproto.py", line 648, in _do_shutdown
#     self._sslobj.unwrap()
#   File "/usr/lib/python3.11/ssl.py", line 983, in unwrap
#     return self._sslobj.shutdown()
#            ^^^^^^^^^^^^^^^^^^^^^^^
# ssl.SSLError: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)
#
# The above exception was the direct cause of the following exception:
#
# aiohttp.client_exceptions.ClientConnectionError: Connection lost: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=ClientConnectionError('Connection lost: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)')>
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/asyncio/sslproto.py", line 648, in _do_shutdown
#     self._sslobj.unwrap()
#   File "/usr/lib/python3.11/ssl.py", line 983, in unwrap
#     return self._sslobj.shutdown()
#            ^^^^^^^^^^^^^^^^^^^^^^^
# ssl.SSLError: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)
#
# The above exception was the direct cause of the following exception:
#
# aiohttp.client_exceptions.ClientConnectionError: Connection lost: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=ClientConnectionError('Connection lost: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)')>
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/asyncio/sslproto.py", line 648, in _do_shutdown
#     self._sslobj.unwrap()
#   File "/usr/lib/python3.11/ssl.py", line 983, in unwrap
#     return self._sslobj.shutdown()
#            ^^^^^^^^^^^^^^^^^^^^^^^
# ssl.SSLError: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)
#
# The above exception was the direct cause of the following exception:
#
# aiohttp.client_exceptions.ClientConnectionError: Connection lost: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=ClientConnectionError('Connection lost: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)')>
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/asyncio/sslproto.py", line 648, in _do_shutdown
#     self._sslobj.unwrap()
#   File "/usr/lib/python3.11/ssl.py", line 983, in unwrap
#     return self._sslobj.shutdown()
#            ^^^^^^^^^^^^^^^^^^^^^^^
# ssl.SSLError: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)
#
# The above exception was the direct cause of the following exception:
#
# aiohttp.client_exceptions.ClientConnectionError: Connection lost: [SSL: APPLICATION_DATA_AFTER_CLOSE_NOTIFY] application data after close notify (_ssl.c:2716)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/OpenPI/openpi/.venv/lib/python3.11/site-packages/orbax/checkpoint/_src/serialization/serialization.py:441, in _read_array_index_and_device_put(devices, index, t, global_shape, new_shard_shape, dtype, byte_limiter, strict, dll, memory_kind)
#     440 try:
# --> 441   shard = await _read_shard(
#     442       t=t,
#     443       new_shard_shape=new_shard_shape,
#     444       dtype=dtype,
#     445       requested_domain=requested_domain,
#     446       restricted_domain=restricted_domain,
#     447   )
#     448 except BaseException as e:
#
# File ~/OpenPI/openpi/.venv/lib/python3.11/site-packages/orbax/checkpoint/_src/serialization/serialization.py:383, in _read_shard(t, new_shard_shape, dtype, requested_domain, restricted_domain)
#     382 out = np.zeros(new_shard_shape, dtype=t.dtype.numpy_dtype)
# --> 383 await ts.array(out)[ts.d[:].translate_to[requested_domain.origin]][
#     384     restricted_domain
#     385 ].write(t[restricted_domain])
#     386 if dtype is not None:
#     387   # Cast while reloading on process to avoid 2 copies on device if the
#     388   # casting is done on device.
#
# File /usr/lib/python3.11/asyncio/futures.py:287, in Future.__await__(self)
#     286     self._asyncio_future_blocking = True
# --> 287     yield self  # This tells Task to wait for completion.
#     288 if not self.done():
#
# File /usr/lib/python3.11/asyncio/tasks.py:349, in Task.__wakeup(self, future)
#     348 try:
# --> 349     future.result()
#     350 except BaseException as exc:
#     351     # This may also be a cancellation.
#
# File /usr/lib/python3.11/asyncio/futures.py:203, in Future.result(self)
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# ValueError: OUT_OF_RANGE: Error reading "params.PaliGemma.llm.layers.mlp.gating_einsum/0.0.0.3" in OCDBT database at local file "/home/yahuanshi/.cache/openpi/openpi-assets/checkpoints/pi0_fast_droid/params/": Requested byte range [0, 1119032607) is not valid for value of size 678755098 [source locations='tensorstore/kvstore/batch_util.h:340\ntensorstore/internal/cache/kvs_backed_cache.h:220']
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 checkpoint_dir = download.maybe_download("gs://openpi-assets/checkpoints/pi0_fast_droid")
#       4 # Create a trained policy.
# ----> 5 policy = _policy_config.create_trained_policy(config, checkpoint_dir)
#       7 # Run inference on a dummy example. This example corresponds to observations produced by the DROID runtime.
#       8 example = droid_policy.make_droid_example()
#
# File ~/OpenPI/openpi/src/openpi/policies/policy_config.py:57, in create_trained_policy(train_config, checkpoint_dir, repack_transforms, sample_kwargs, default_prompt, norm_stats, pytorch_device)
#      55     model.paligemma_with_expert.to_bfloat16_for_selected_params("bfloat16")
#      56 else:
# ---> 57     model = train_config.model.load(_model.restore_params(checkpoint_dir / "params", dtype=jnp.bfloat16))
#      58 data_config = train_config.data.create(train_config.assets_dirs, train_config.model)
#      59 if norm_stats is None:
#      60     # We are loading the norm stats from the checkpoint instead of the config assets dir to make sure
#      61     # that the policy is using the same normalization stats as the original training process.
#
# File ~/OpenPI/openpi/src/openpi/models/model.py:317, in restore_params(params_path, restore_type, dtype, sharding)
#     314     metadata = ckptr.metadata(params_path)
#     315     item = {"params": metadata["params"]}
# --> 317     params = ckptr.restore(
#     318         params_path,
#     319         ocp.args.PyTreeRestore(
#     320             item=item,
#     321             restore_args=jax.tree.map(
#     322                 lambda _: ocp.ArrayRestoreArgs(sharding=sharding, restore_type=restore_type, dtype=dtype), item
#     323             ),
#     324         ),
#     325     )["params"]
#     327 # If the params were saved with `save_state` during openpi training, every key path will end with "value", which is
#     328 # added by `nnx.State`. We remove the "value" suffix here and always return what NNX calls a "pure dict".
#     329 flat_params = traverse_util.flatten_dict(params)
#
# File ~/OpenPI/openpi/.venv/lib/python3.11/site-packages/orbax/checkpoint/_src/checkpointers/checkpointer.py:300, in Checkpointer.restore(self, directory, *args, **kwargs)
#     298 logging.info('Restoring checkpoint from %s.', directory)
#     299 ckpt_args = construct_checkpoint_args(self._handler, False, *args, **kwargs)
# --> 300 restored = self._restore(directory, args=ckpt_args)
#     301 multihost.sync_global_processes(
#     302     multihost.unique_barrier_key(
#     303         'Checkpointer:restore',
#    (...)    306     processes=self._active_processes,
#     307 )
#     308 restore_duration_secs = time.time() - restore_start_time
#
# File ~/OpenPI/openpi/.venv/lib/python3.11/site-packages/orbax/checkpoint/_src/checkpointers/checkpointer.py:319, in Checkpointer._restore(self, directory, args)
#     316 def _restore(
#     317     self, directory: epath.PathLike, args: checkpoint_args.CheckpointArgs
#     318 ) -> Any:
# --> 319   return self._handler.restore(directory, args=args)
#
# File ~/OpenPI/openpi/.venv/lib/python3.11/site-packages/orbax/checkpoint/_src/handlers/pytree_checkpoint_handler.py:796, in PyTreeCheckpointHandler.restore(self, directory, item, restore_args, transforms, transforms_default_to_original, legacy_transform_fn, args)
#     786 if (
#     787     (directory / PYTREE_METADATA_FILE).exists()
#     788     and can_ignore_aggregate_file
#     789     and transforms is None
#     790     and legacy_transform_fn is None
#     791 ):
#     792   args = BasePyTreeRestoreArgs(
#     793       item,
#     794       restore_args=restore_args,
#     795   )
# --> 796   return self._handler_impl.restore(directory, args=args)
#     798 logging.vlog(1, 'directory=%s, restore_args=%s', directory, restore_args)
#     799 if not directory.exists():
#
# File ~/OpenPI/openpi/.venv/lib/python3.11/site-packages/orbax/checkpoint/_src/handlers/base_pytree_checkpoint_handler.py:760, in BasePyTreeCheckpointHandler.restore(self, directory, args)
#     752 param_infos = self._get_param_infos(
#     753     item=value_metadata_tree,
#     754     directory=directory,
#    (...)    757     raise_array_data_missing_error=raise_array_data_missing_error,
#     758 )
#     759 # Begin restore.
# --> 760 tree_memory_size, restored_item = asyncio_utils.run_sync(
#     761     self._maybe_deserialize(
#     762         item, value_metadata_tree, param_infos, restore_args
#     763     )
#     764 )
#     766 if logging.vlog_is_on(1):
#     767   logging.vlog(1, 'param_infos: %s', param_infos)
#
# File ~/OpenPI/openpi/.venv/lib/python3.11/site-packages/orbax/checkpoint/_src/asyncio_utils.py:50, in run_sync(coro, enable_nest_asyncio)
#      48 except RuntimeError:
#      49   pass
# ---> 50 return asyncio.run(coro)
#
# File ~/OpenPI/openpi/.venv/lib/python3.11/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/OpenPI/openpi/.venv/lib/python3.11/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File /usr/lib/python3.11/asyncio/futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File /usr/lib/python3.11/asyncio/tasks.py:279, in Task.__step(***failed resolving arguments***)
#     277         result = coro.send(None)
#     278     else:
# --> 279         result = coro.throw(exc)
#     280 except StopIteration as exc:
#     281     if self._must_cancel:
#     282         # Task is cancelled right before coro stops.
#
# File ~/OpenPI/openpi/.venv/lib/python3.11/site-packages/orbax/checkpoint/_src/handlers/base_pytree_checkpoint_handler.py:584, in BasePyTreeCheckpointHandler._maybe_deserialize(self, item, metadata, param_infos, restore_args)
#     580 for request in batch_requests:
#     581   deserialized_batches_ops.append(
#     582       request.handler.deserialize(request.infos, request.args)
#     583   )
# --> 584 deserialized_batches += await asyncio.gather(*deserialized_batches_ops)
#     586 tree_memory_size = 0
#     587 flat_restored = {}
#
# File /usr/lib/python3.11/asyncio/tasks.py:349, in Task.__wakeup(self, future)
#     347 def __wakeup(self, future):
#     348     try:
# --> 349         future.result()
#     350     except BaseException as exc:
#     351         # This may also be a cancellation.
#     352         self.__step(exc)
#
# File /usr/lib/python3.11/asyncio/tasks.py:279, in Task.__step(***failed resolving arguments***)
#     277         result = coro.send(None)
#     278     else:
# --> 279         result = coro.throw(exc)
#     280 except StopIteration as exc:
#     281     if self._must_cancel:
#     282         # Task is cancelled right before coro stops.
#
# File ~/OpenPI/openpi/.venv/lib/python3.11/site-packages/orbax/checkpoint/_src/serialization/type_handlers.py:1314, in ArrayHandler.deserialize(self, infos, args)
#    1308 if self._array_metadata_store is not None:
#    1309   deserialize_ops.append(
#    1310       self._array_metadata_store.read(
#    1311           checkpoint_dir=infos[0].parent_dir,
#    1312       )
#    1313   )
# -> 1314   *ret, array_metadatas = await asyncio.gather(*deserialize_ops)
#    1316   if array_metadatas:
#    1317     ret = self._parse_array_metadatas(array_metadatas, infos, ret)
#
# File /usr/lib/python3.11/asyncio/tasks.py:349, in Task.__wakeup(self, future)
#     347 def __wakeup(self, future):
#     348     try:
# --> 349         future.result()
#     350     except BaseException as exc:
#     351         # This may also be a cancellation.
#     352         self.__step(exc)
#
# File /usr/lib/python3.11/asyncio/tasks.py:279, in Task.__step(***failed resolving arguments***)
#     277         result = coro.send(None)
#     278     else:
# --> 279         result = coro.throw(exc)
#     280 except StopIteration as exc:
#     281     if self._must_cancel:
#     282         # Task is cancelled right before coro stops.
#
# File ~/OpenPI/openpi/.venv/lib/python3.11/site-packages/orbax/checkpoint/_src/serialization/serialization.py:544, in async_deserialize(user_sharding, tensorstore_spec, global_shape, dtype, byte_limiter, context, assume_metadata, strict)
#     542 global_shape = tuple(t.shape if global_shape is None else global_shape)
#     543 new_shard_shape = sharding.shard_shape(global_shape)
# --> 544 return await read_and_create_array(
#     545     t,
#     546     global_shape=global_shape,
#     547     new_shard_shape=new_shard_shape,
#     548     sharding=sharding,
#     549     dtype=dtype,
#     550     byte_limiter=byte_limiter,
#     551     strict=strict,
#     552     dll=dll,
#     553 )
#
# File ~/OpenPI/openpi/.venv/lib/python3.11/site-packages/orbax/checkpoint/_src/serialization/serialization.py:503, in read_and_create_array(t, global_shape, new_shard_shape, sharding, dtype, byte_limiter, strict, dll)
#     484     local_indices_devices_map[
#     485         np_utils.to_hashable_index(idx, shape=global_shape)
#     486     ].append(d)
#     488 read_array_coros = [
#     489     _read_array_index_and_device_put(
#     490         devices,
#    (...)    501     for idx, devices in local_indices_devices_map.items()
#     502 ]
# --> 503 dbs = sum(await asyncio.gather(*read_array_coros), [])
#     504 return jax.make_array_from_single_device_arrays(global_shape, sharding, dbs)
#
# File /usr/lib/python3.11/asyncio/tasks.py:349, in Task.__wakeup(self, future)
#     347 def __wakeup(self, future):
#     348     try:
# --> 349         future.result()
#     350     except BaseException as exc:
#     351         # This may also be a cancellation.
#     352         self.__step(exc)
#
# File /usr/lib/python3.11/asyncio/tasks.py:279, in Task.__step(***failed resolving arguments***)
#     277         result = coro.send(None)
#     278     else:
# --> 279         result = coro.throw(exc)
#     280 except StopIteration as exc:
#     281     if self._must_cancel:
#     282         # Task is cancelled right before coro stops.
#
# File ~/OpenPI/openpi/.venv/lib/python3.11/site-packages/orbax/checkpoint/_src/serialization/serialization.py:449, in _read_array_index_and_device_put(devices, index, t, global_shape, new_shard_shape, dtype, byte_limiter, strict, dll, memory_kind)
#     441   shard = await _read_shard(
#     442       t=t,
#     443       new_shard_shape=new_shard_shape,
#    (...)    446       restricted_domain=restricted_domain,
#     447   )
#     448 except BaseException as e:
# --> 449   raise Exception(  # pylint: disable=broad-exception-raised
#     450       f'Encountered error while reading array index: {index}. See full'
#     451       f' TensorStore details: {t.spec}.'
#     452   ) from e
#     453 for device in devices:
#     454   sharding = jax.sharding.SingleDeviceSharding(
#     455       device, memory_kind=memory_kind
#     456   )
#
# Exception: Encountered error while reading array index: (slice(0, 18, 1), slice(0, 2, 1), slice(0, 2048, 1), slice(0, 16384, 1)). See full TensorStore details: <bound method PyCapsule.spec of TensorStore({
#   'base': {
#     'driver': 'zarr',
#     'dtype': 'float32',
#     'fill_missing_data_reads': False,
#     'kvstore': {
#       'base': {
#         'driver': 'file',
#         'path': '/home/yahuanshi/.cache/openpi/openpi-assets/checkpoints/pi0_fast_droid/params/',
#       },
#       'cache_pool': 'cache_pool#ocdbt',
#       'config': {
#         'compression': {'id': 'zstd'},
#         'max_decoded_node_bytes': 100000000,
#         'max_inline_value_bytes': 1024,
#         'uuid': 'ca888d2fcf3b0d15d240930fdc9d4ce1',
#         'version_tree_arity_log2': 4,
#       },
#       'driver': 'ocdbt',
#       'path': 'params.PaliGemma.llm.layers.mlp.gating_einsum/',
#     },
#     'metadata': {
#       'chunks': [18, 2, 2048, 4096],
#       'compressor': {'id': 'zstd', 'level': 1},
#       'dimension_separator': '.',
#       'dtype': '<f4',
#       'fill_value': None,
#       'filters': None,
#       'order': 'C',
#       'shape': [18, 2, 2048, 16384],
#       'zarr_format': 2,
#     },
#     'recheck_cached_data': False,
#     'recheck_cached_metadata': False,
#   },
#   'context': {
#     'cache_pool': {},
#     'cache_pool#ocdbt': {'total_bytes_limit': 100000000},
#     'data_copy_concurrency': {},
#     'file_io_concurrency': {'limit': 128},
#     'file_io_locking': {},
#     'file_io_memmap': False,
#     'file_io_sync': True,
#     'ocdbt_coordinator': {},
#   },
#   'driver': 'cast',
#   'dtype': 'bfloat16',
#   'transform': {
#     'input_exclusive_max': [[18], [2], [2048], [16384]],
#     'input_inclusive_min': [0, 0, 0, 0],
#   },
# })>.

# %% [markdown]
# # Working with a live model
#
#
# The following example shows how to create a live model from a checkpoint and compute training loss. First, we are going to demonstrate how to do it with fake data.

# %%
config = _config.get_config("pi0_aloha_sim")

checkpoint_dir = download.maybe_download("gs://openpi-assets/checkpoints/pi0_aloha_sim")
key = jax.random.key(0)

# Create a model from the checkpoint.
model = config.model.load(_model.restore_params(checkpoint_dir / "params"))

# We can create fake observations and actions to test the model.
obs, act = config.model.fake_obs(), config.model.fake_act()

# Sample actions from the model.
loss = model.compute_loss(key, obs, act)
print("Loss shape:", loss.shape)

# %% [markdown]
# Now, we are going to create a data loader and use a real batch of training data to compute the loss.

# %%
# Reduce the batch size to reduce memory usage.
config = dataclasses.replace(config, batch_size=2)

# Load a single batch of data. This is the same data that will be used during training.
# NOTE: In order to make this example self-contained, we are skipping the normalization step
# since it requires the normalization statistics to be generated using `compute_norm_stats`.
loader = _data_loader.create_data_loader(config, num_batches=1, skip_norm_stats=True)
obs, act = next(iter(loader))

# Sample actions from the model.
loss = model.compute_loss(key, obs, act)

# Delete the model to free up memory.
del model

print("Loss shape:", loss.shape)
